# %% [markdown]
# # RNN Sequence Prediction com TensorFlow 2.0
# # Regressão

# %%
import tensorflow as tf
import numpy as np

from tensorflow import keras
from tensorflow.keras import datasets, layers, models

# %%
tf.__version__
# Out:
# '2.0.0-beta1'

# %% [markdown]
# # Dados de teste

# %%
data = [[i for i in range(100)]]
data = np.array(data, dtype=float)
target = [[i for i in range(1,101)]]
target = np.array(target, dtype=float)

data = data.reshape((1, 1, 100)) 
target = target.reshape((1, 1, 100)) 
x_test=[i for i in range(100,200)]
x_test=np.array(x_test).reshape((1,1,100));
y_test=[i for i in range(101,201)]
y_test=np.array(y_test).reshape(1,1,100)

# %% [markdown]
# # Modelo RNN

# %%
model = models.Sequential()
model.add(layers.LSTM(100, input_shape=(1, 100),return_sequences=True))
model.add(layers.Dense(units=100))

# %% [markdown]
# # Compilar e Ajustar o Modelo

# %%
# Como é um problema de regressão utiliza-se o mean_absolute_error
model.compile(loss='mean_absolute_error', optimizer='adam',metrics=['accuracy'])

# %%
model.fit(data, target, nb_epoch=1000, batch_size=1, verbose=2,validation_data=(x_test, y_test))
# Out:
# W0619 13:45:03.594564  8348 training.py:617] The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 1 samples, validate on 1 samples
# Epoch 1/1000
# 1/1 - 1s - loss: 50.4895 - accuracy: 0.0000e+00 - val_loss: 150.4437 - val_accuracy: 0.0000e+00
# Epoch 2/1000
# 1/1 - 0s - loss: 50.3906 - accuracy: 0.0000e+00 - val_loss: 150.3607 - val_accuracy: 0.0000e+00
# Epoch 3/1000
# 1/1 - 0s - loss: 50.3533 - accuracy: 0.0000e+00 - val_loss: 150.3439 - val_accuracy: 0.0000e+00
# Epoch 4/1000
# 1/1 - 0s - loss: 50.3283 - accuracy: 0.0000e+00 - val_loss: 150.3165 - val_accuracy: 0.0000e+00
# Epoch 5/1000
# 1/1 - 0s - loss: 50.3044 - accuracy: 0.0000e+00 - val_loss: 150.2936 - val_accuracy: 0.0000e+00
# Epoch 6/1000
# 1/1 - 0s - loss: 50.2808 - accuracy: 0.0000e+00 - val_loss: 150.2704 - val_accuracy: 0.0000e+00
# Epoch 7/1000
# 1/1 - 0s - loss: 50.2570 - accuracy: 0.0000e+00 - val_loss: 150.2468 - val_accuracy: 0.0000e+00
# Epoch 8/1000
# ...

# %% [markdown]
# # Previsões com o Modelo

# %%
result = model.predict(data)

# %%
result
# Out:
# array([[[ 0.9983808,  1.9983107,  3.007239 ,  4.0031185,  5.000127 ,
#           5.9987326,  6.998389 ,  8.000638 ,  9.002863 , 10.001807 ,
#          11.00421  , 12.000426 , 13.002007 , 14.002342 , 15.000532 ,
#          16.003044 , 17.007044 , 18.009481 , 18.996479 , 20.001827 ,
#          21.004295 , 21.99858  , 23.00444  , 23.986094 , 25.000502 ,
#          25.999765 , 27.009207 , 28.076117 , 28.410566 , 28.406546 ,
#          28.189154 , 29.340353 , 28.722172 , 28.783424 , 29.169733 ,
#          28.60247  , 28.996815 , 29.121874 , 28.680008 , 28.479378 ,
#          28.44406  , 28.974615 , 29.036789 , 28.991844 , 28.919125 ,
#          28.350695 , 29.491957 , 29.167542 , 28.07437  , 28.389402 ,
#          29.212286 , 27.978113 , 27.995611 , 27.507648 , 29.402653 ,
#          28.574245 , 28.685938 , 27.823812 , 28.06798  , 29.631498 ,
#          28.262358 , 28.2486   , 28.66272  , 29.074377 , 29.25191  ,
#          28.339079 , 29.113674 , 28.58912  , 28.405636 , 28.970566 ,
# ...
